# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime

# %%
data = pd.read_csv(r"C:\Users\halwa\OneDrive\Desktop\Algo\data. csv")

# %%
data
# Out:
#             Date      Open      High       Low     Close  Shares Traded  \
# 0    30-Sep-2021  17718.90  17742.15  17585.35  17618.15      378592721
# 1    01-Oct-2021  17531.90  17557.15  17452.90  17532.05      305763919
# 2    04-Oct-2021  17615.55  17750.90  17581.35  17691.25      295761839
# 3    05-Oct-2021  17661.35  17833.45  17640.90  17822.30      427000191
# 4    06-Oct-2021  17861.50  17884.60  17613.15  17646.00      395833550
# ..           ...       ...       ...       ...       ...            ...
# 224  25-Aug-2022  17679.00  17726.50  17487.45  17522.45      230181848
# 225  26-Aug-2022  17619.30  17685.85  17519.35  17558.90      266636238
# 226  29-Aug-2022  17188.65  17380.15  17166.20  17312.90      244854637
# 227  30-Aug-2022  17414.95  17777.65  17401.50  17759.30      324687477
# 228  01-Sep-2022  17485.70  17695.60  17468.45  17542.80      308526598
#
#      Turnover (Rs. Cr)
# 0             27167.19
# 1             20911.61
# 2             21343.51
# ...

# %%
data = data.set_index(pd.DatetimeIndex(data['Date'].values))

# %%
plt.figure(figsize=(16,8))
plt.title('Close Price')
plt.plot(data['Close'])
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.show()

# %%
period1 = 20
period2 = 66

# SMA

data['SMA1'] = data['Close'].rolling(window = period1).mean()
data['SMA2'] = data['Close'].rolling(window = period2).mean()

# %%
# Standard Deviation

# data['STD'] = data['Close'].rolling(window = period).std()

# %%
# Upper Bollinger Band

# data['Upper'] = data['SMA'] + ( data['STD'] * 2 )

# %%
# Lower Bollinger Band

# data['Lower'] = data['SMA'] - (data['STD'] * 2)

# %%
# List of columns

column_list = ['Close', 'SMA1', 'SMA2']

# %%
data.dropna(inplace=True)
data
# Out:
#                    Date      Open      High       Low     Close  \
# 2022-01-04  04-Jan-2022  17681.40  17827.60  17593.55  17805.25
# 2022-01-05  05-Jan-2022  17820.10  17944.70  17748.85  17925.25
# 2022-01-06  06-Jan-2022  17768.50  17797.95  17655.55  17745.90
# 2022-01-07  07-Jan-2022  17797.60  17905.00  17704.55  17812.70
# 2022-01-10  10-Jan-2022  17913.30  18017.45  17879.15  18003.30
# ...                 ...       ...       ...       ...       ...
# 2022-08-25  25-Aug-2022  17679.00  17726.50  17487.45  17522.45
# 2022-08-26  26-Aug-2022  17619.30  17685.85  17519.35  17558.90
# 2022-08-29  29-Aug-2022  17188.65  17380.15  17166.20  17312.90
# 2022-08-30  30-Aug-2022  17414.95  17777.65  17401.50  17759.30
# 2022-09-01  01-Sep-2022  17485.70  17695.60  17468.45  17542.80
#
#             Shares Traded  Turnover (Rs. Cr)        SMA1          SMA2
# 2022-01-04      247437472           18604.16  17229.2475  17618.781061
# ...

# %%
# plot the data

data[column_list].plot(figsize = (12.2, 6.4))
plt.title('Close')
plt.ylabel('Price')
plt.show()

# %%
a = -1 + 3 -1 +3 +3 
print(a)
# Out:
# 7
